# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 42.9 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 39.7 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
import transformers

# %%
# !pip install transformers[sentencepiece]
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 5.3 MB/s
# ...

# %%
from transformers import pipeline

# %% [markdown]
# **Name Entities Recognition**

# %%
ner = pipeline('ner', grouped_entities = True)
ner('My name is Gulchin and I work at Google in Reston.')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english)
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="AggregationStrategy.SIMPLE"` instead.
#   f'`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="{aggregation_strategy}"` instead.'
# [{'end': 18,
#   'entity_group': 'PER',
#   'score': 0.9840245,
#   'start': 11,
#   'word': 'Gulchin'},
#  {'end': 39,
#   'entity_group': 'ORG',
#   'score': 0.9989945,
#   'start': 33,
#   'word': 'Google'},
#  {'end': 49,
#   'entity_group': 'LOC',
#   'score': 0.958475,
#   'start': 43,
#   'word': 'Reston'}]

# %% [markdown]
# # **sentiment analysis**

# %%
classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598048329353333},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %% [markdown]
# ## classify texts that haven’t been **labelled**  , Zero-shot-classification

# %%
classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business",'sport','finance'],
)
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli (https://huggingface.co/facebook/bart-large-mnli)
# {'labels': ['education', 'business', 'sport', 'finance', 'politics'],
#  'scores': [0.7410706877708435,
#   0.09824896603822708,
#   0.06779065728187561,
#   0.05478597432374954,
#   0.03810383379459381],
#  'sequence': 'This is a course about the Transformers library'}

# %% [markdown]
# Text **Generation**

# %%
generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to create and deploy your own secure CloudDB on Android using PYTHON.PYTHON provides easy to navigate and maintain your own PYTHON server at a minimum with an additional layer'}]

# %%
generator('Today i want to go')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Today i want to go back and enjoy my life, not to write about it a bunch. i'm still having nightmares about things like this, but still I wanted to put my best foot forward when i got back home and this article that i wrote"}]

# %%
generator('I go to school')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'I go to school for a job," she says, holding the box in her hand, which seems to me to remind her of the first time she spent in a military-blue uniform. In her class, she is an honors-student student,'}]

# %%
generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=30,
    num_return_sequences=2,
)
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to avoid the use of this software that can lead to serious health problems. I want to encourage you to'},
#  {'generated_text': 'In this course, we will teach you how to avoid unnecessary delays without resorting to the standard method. If we are not sure what to expect in'}]

# %% [markdown]
# # **Mask filling**

# %% [markdown]
# The idea of this task is to fill in the blanks in a given text:
# The top_k argument controls how many possibilities you want to be displayed

# %%
unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> models.", top_k=2)
